# %% [markdown]
# # Plots in python
# - https://www.activestate.com/resources/quick-reads/how-to-display-a-plot-in-python/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data

# %%
mtcars = data('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# # complex Plots
# -  Axis method

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3])
ax.set_title('Axis method of Plot')
plt.show();

# %%
wtmpg = mtcars.loc[:,['wt','mpg']].sort_values(by='wt')
fig, ax = plt.subplots()
ax.scatter(wtmpg.wt, wtmpg.mpg)
ax.set_title('MT cars')
plt.show();

# %%
# Create a Figure with 2 rows and 2 columns of subplots:
fig, ax = plt.subplots(2, 2)
x = np.linspace(0, 5, 100)
# Index 4 Axes arrays in 4 subplots within 1 Figure: 
ax[0, 0].plot(x, np.sin(x), 'g') #row=0, column=0
ax[1, 0].plot(range(100), 'b') #row=1, column=0
ax[0, 1].plot(x, np.cos(x), 'r') #row=0, column=1
ax[1, 1].plot(x, np.tan(x), 'k') #row=1, column=1
plt.show()

# %%
# Histogram

# %%
import matplotlib.ticker as maticker
# Create random variable:
data = np.random.normal(0, 3, 800)
# Create a Figure and multiple subplots containing Axes:
weights = np.ones_like(data) / len(data)
data[0:5]
# Out:
# array([-0.49576998,  0.82609563,  1.1410584 , -2.14746095,  7.68102656])

# %%
# Create Histogram Axe:
fig, ax = plt.subplots()
ax.hist(data, bins=5, weights=weights)
ax.yaxis.set_major_formatter(maticker.PercentFormatter(xmax=1.0, decimals=1))
plt.title('Histogram Plot')
plt.show()

# %% [markdown]
# # links
# - https://towardsdatascience.com/what-are-the-plt-and-ax-in-matplotlib-exactly-d2cf4bf164a9
