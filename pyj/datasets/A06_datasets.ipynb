# %% [markdown]
# # Python Datasets
# - https://towardsdatascience.com/datasets-in-python-425475a20eb1

# %% [markdown]
# ## Dataset
# - !pip install datasets
# - https://pypi.org/project/datasets/
# - not working properly

# %%
import datasets
import datetime
import numpy as np
import pandas as pd
print(datasets.__version__)
# Out:
# 2.12.0

# %%
from datasets import load_dataset

# %%
#load_dataset('squad')

# %% [markdown]
# # Pydataset
# - !pip install pydataset

# %%
from pydataset import data

# %%
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
', '.join(data().dataset_id)
# Out:
# 'AirPassengers, BJsales, BOD, Formaldehyde, HairEyeColor, InsectSprays, JohnsonJohnson, LakeHuron, LifeCycleSavings, Nile, OrchardSprays, PlantGrowth, Puromycin, Titanic, ToothGrowth, UCBAdmissions, UKDriverDeaths, UKgas, USAccDeaths, USArrests, USJudgeRatings, USPersonalExpenditure, VADeaths, WWWusage, WorldPhones, airmiles, airquality, anscombe, attenu, attitude, austres, cars, chickwts, co2, crimtab, discoveries, esoph, euro, faithful, freeny, infert, iris, islands, lh, longley, lynx, morley, mtcars, nhtemp, nottem, npk, occupationalStatus, precip, presidents, pressure, quakes, randu, rivers, rock, sleep, stackloss, sunspot.month, sunspot.year, sunspots, swiss, treering, trees, uspop, volcano, warpbreaks, women, acme, aids, aircondit, aircondit7, amis, aml, bigcity, brambles, breslow, calcium, cane, capability, catsM, cav, cd4, channing, city, claridge, cloth, co.transfer, coal, darwin, dogs, downs.bc, ducks, fir, frets, grav, gravity, hirose, islay, manaus, melanoma, motor, neuro
# ...

# %% [markdown]
# ## mtcars(data)

# %%
mtcars = data('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# ## sleepstudy (data)

# %%
sleepstudy = data('sleepstudy')
sleepstudy.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %% [markdown]
# ## iris (data)

# %%
iris = data('iris')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## airpassengers (data)

# %%
airp = data('AirPassengers')
airp.head()
# Out:
#           time  AirPassengers
# 1  1949.000000            112
# 2  1949.083333            118
# 3  1949.166667            132
# 4  1949.250000            129
# 5  1949.333333            121

# %%
from datetime import datetime, timedelta
airp['date']= airp['time'].apply(lambda x : datetime(int(x), 1, 1) + timedelta(days = (x % 1) * 365+1))
airp.head()
# Out:
#           time  AirPassengers                       date
# 1  1949.000000            112 1949-01-02 00:00:00.000000
# 2  1949.083333            118 1949-02-01 09:59:59.999897
# 3  1949.166667            132 1949-03-03 20:00:00.000103
# 4  1949.250000            129 1949-04-03 06:00:00.000000
# 5  1949.333333            121 1949-05-03 15:59:59.999897

# %%
airp['monYr'] = airp['date'].dt.strftime('%b-%Y')
airp.head()
# Out:
#           time  AirPassengers                       date     monYr
# 1  1949.000000            112 1949-01-02 00:00:00.000000  Jan-1949
# 2  1949.083333            118 1949-02-01 09:59:59.999897  Feb-1949
# 3  1949.166667            132 1949-03-03 20:00:00.000103  Mar-1949
# 4  1949.250000            129 1949-04-03 06:00:00.000000  Apr-1949
# 5  1949.333333            121 1949-05-03 15:59:59.999897  May-1949

# %% [markdown]
# # vega_datasets
# -

# %%
#!pip install vega_datasets

# %%
from vega_datasets import local_data

# %%
', '.join(local_data.list_datasets())
# Out:
# 'airports, anscombe, barley, burtin, cars, crimea, driving, iowa-electricity, iris, la-riots, ohlc, seattle-temps, seattle-weather, sf-temps, stocks, us-employment, wheat'

# %% [markdown]
# ## cars

# %%
cars = local_data.cars()
cars.shape
# Out:
# (406, 9)

# %%
cars.columns
# Out:
# Index(['Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
#        'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#       dtype='object')

# %%
# yahoo
#!pip install yahoo
#!pip install yfinance

# %%
import yfinance as yf
 
# Get the data for the stock Microsoft
data = yf.download('MSFT', start="2020-01-01", end="2024-03-12")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-05  413.959991  414.250000  400.640015  402.649994  402.649994
# 2024-03-06  402.970001  405.160004  398.390015  402.089996  402.089996
# 2024-03-07  406.119995  409.779999  402.239990  409.140015  409.140015
# 2024-03-08  407.959991  410.420013  404.329987  406.220001  406.220001
# 2024-03-11  403.760010  405.679993  401.260010  404.519989  404.519989
#
#               Volume
# Date
# 2024-03-05  26919200
# 2024-03-06  22344100
# 2024-03-07  18718500
# 2024-03-08  17971700
# 2024-03-11  16093600

# %% [markdown]
# # statsmodel

# %%
import statsmodels.api as sm

# %% [markdown]
# ## cancer

# %%
data = sm.datasets.cancer.load_pandas()

# %%
data.data
# Out:
#      cancer  population
# 0       1.0       445.0
# 1       0.0       559.0
# 2       3.0       677.0
# 3       4.0       681.0
# 4       3.0       746.0
# ..      ...         ...
# 296   250.0     62931.0
# 297   267.0     63476.0
# 298   244.0     66676.0
# 299   248.0     74005.0
# 300   360.0     88456.0
#
# [301 rows x 2 columns]

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %%
', '.join(sns.get_dataset_names())
# Out:
# 'anagrams, anscombe, attention, brain_networks, car_crashes, diamonds, dots, dowjones, exercise, flights, fmri, geyser, glue, healthexp, iris, mpg, penguins, planets, seaice, taxis, tips, titanic'

# %% [markdown]
# ## iris

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## titanic

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # sklearn
# - General dataset API. There are three main kinds of dataset interfaces that can be used to get datasets depending on the desired type of dataset.
# - load, - fetch
# - https://scikit-learn.org/stable/datasets.html

# %%
from sklearn import datasets

# %% [markdown]
# # toy datasets
# - https://scikit-learn.org/stable/datasets/toy_dataset.html

# %%
data = datasets.load_wine(return_X_y = False, as_frame=True)
data = data['frame']
data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
data, target = datasets.load_iris(return_X_y = True, as_frame= True)
data['target'] = target
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## Realworld datasets
# - https://scikit-learn.org/stable/datasets/real_world.html

# %%
data = datasets.fetch_california_housing(return_X_y=False, as_frame=True)
data = data['frame']
data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
data = datasets.fetch_openml(data_id=42437, parser='auto',  as_frame=True, return_X_y=False)
data = data['frame']
data.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  relatives  Title
# 0         0       3    0    2     0         0          1      1
# 1         1       1    1    5     3         1          1      3
# 2         1       3    1    3     0         0          0      2
# 3         1       1    1    5     3         0          1      3
# 4         0       3    0    5     1         0          0      1

# %% [markdown]
# ## Generators
# - https://scikit-learn.org/stable/datasets/sample_generators.html

# %% [markdown]
# ## Other Datasets
# - https://scikit-learn.org/stable/datasets/loading_other_datasets.html
# - openml.org is a public repository for machine learning data and experiments, that allows everybody to upload open datasets
# - https://openml.org/

# %%
data = datasets.fetch_openml('diabetes', parser='auto', version=1, as_frame=True, return_X_y=False)
data = data['frame']
data.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
data = datasets.fetch_openml(data_id=43897, parser='auto', as_frame=True, return_X_y=False)
data = data['frame']
print(data.shape)
print(data.columns)
#ibm-employee-performance
# Out:
# (1470, 34)
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
X, y = datasets.fetch_openml(data_id=43893, parser='auto', as_frame=True, return_X_y=True)

# %%
#type(X)
X['Attrition'] = y
X.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
X[['Age','BusinessTravel', 'DailyRate','Attrition']].head()
# Out:
#    Age     BusinessTravel  DailyRate Attrition
# 0   41      Travel_Rarely       1102       Yes
# 1   49  Travel_Frequently        279        No
# 2   37      Travel_Rarely       1373       Yes
# 3   33  Travel_Frequently       1392        No
# 4   27      Travel_Rarely        591        No

# %%
X.Attrition.value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
# employee salary

# %%
data, target = datasets.fetch_openml(data_id=43543, parser='auto', as_frame=True, return_X_y=True)
data.head()
# Out:
#                Name Gender Date_of_Birth  Age   Join_Date  \
# 0    'Keven Norman'      M        3/9/94   25     2/12/19
# 1  'Kristin Werner'      F    23/06/1994   26  13/01/2020
# 2    'Avery Barber'      M    27/02/1996   24  14/11/2019
# 3    'Boris Gibson'      M    29/09/1993   26  13/01/2020
# 4       'Leif Mack'      M        1/5/91   29      4/6/18
#
#    Tenure_in_org_in_months   GROSS  Net_Pay  Deduction  Deduction_percentage  \
# 0                        7   74922    71494       3428                  4.58
# 1                        6   44375    39971       4404                  9.92
# 2                        8   82263    77705       4558                  5.54
# 3                        6   44375    40164       4211                  9.49
# 4                       25  235405   143963      91442                 38.84
#
#                                  Designation                       Department
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Gender', 'Date_of_Birth', 'Age', 'Join_Date',
#        'Tenure_in_org_in_months', 'GROSS', 'Net_Pay', 'Deduction',
#        'Deduction_percentage', 'Designation', 'Department'],
#       dtype='object')

# %%
data.shape
# Out:
# (1802, 12)

# %% [markdown]
# # OpenML
# -  !pip install openml
# -  https://openml.org/apis
# -  # List all datasets and their properties
# -  openml.datasets.list_datasets(output_format="dataframe")
# -  # Get dataset by ID
# -  dataset = openml.datasets.get_dataset(61)
# -  # Get dataset by name
# -  dataset = openml.datasets.get_dataset('Fashion-MNIST')
# -  # Get the data itself as a dataframe (or otherwise)
# -  X, y, _, _ = dataset.get_data(dataset_format="dataframe")

# %%
# List all datasets and their properties
import openml
openmlDS = openml.datasets.list_datasets(output_format="dataframe")

# %%
openmlDS.columns
# Out:
# Index(['did', 'name', 'version', 'uploader', 'status', 'format',
#        'MajorityClassSize', 'MaxNominalAttDistinctValues', 'MinorityClassSize',
#        'NumberOfClasses', 'NumberOfFeatures', 'NumberOfInstances',
#        'NumberOfInstancesWithMissingValues', 'NumberOfMissingValues',
#        'NumberOfNumericFeatures', 'NumberOfSymbolicFeatures'],
#       dtype='object')

# %%
openmlDS[['did','name','format','NumberOfInstances']].head()
# Out:
#    did        name format  NumberOfInstances
# 2    2      anneal   ARFF              898.0
# 3    3    kr-vs-kp   ARFF             3196.0
# 4    4       labor   ARFF               57.0
# 5    5  arrhythmia   ARFF              452.0
# 6    6      letter   ARFF            20000.0

# %%
openmlDS[openmlDS['name'].str.contains('adult')]
# Out:
#          did                                                         name  \
# 179      179                                                        adult
# 1119    1119                                                 adult-census
# 1182    1182                                                   BNG(adult)
# 1590    1590                                                        adult
# 42104  42104                                               adult_income_p
# 42878  42878                                            autism-adult-data
# 43898  43898                                                        adult
# 44723  44723  adult_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True
# 44724  44724  adult_seed_1_nrows_2000_nclasses_10_ncols_100_stratify_True
# 44725  44725  adult_seed_2_nrows_2000_nclasses_10_ncols_100_stratify_True
# 44726  44726  adult_seed_3_nrows_2000_nclasses_10_ncols_100_stratify_True
# 44727  44727  adult_seed_4_nrows_2000_nclasses_10_ncols_100_stratify_True
# ...

# %%
openmlDS.format.value_counts()
# Out:
# format
# arff           2405
# ARFF           1882
# Sparse_ARFF    1149
# sparse_arff       1
# Name: count, dtype: int64

# %%
openmlDS.version.value_counts()
# Out:
# version
# 1     4185
# 2      594
# 3      181
# 4      101
# 5       64
# 6       50
# 7       42
# 8       29
# 9       27
# 11      14
# 10      13
# 12      12
# 14      10
# 16      10
# 15       9
# 13       7
# 17       6
# 19       5
# 18       4
# 21       4
# 22       4
# 24       3
# 26       3
# 27       3
# 20       3
# 23       3
# 25       2
# 40       2
# 51       2
# 50       2
# 49       2
# 48       2
# 47       2
# 46       2
# 45       2
# 44       2
# 43       2
# 42       2
# 41       2
# 39       2
# 38       2
# 37       2
# 36       2
# 35       2
# 34       2
# 33       2
# 32       2
# 31       2
# 30       2
# 29       2
# 28       2
# 52       1
# Name: count, dtype: int64

# %%
openmlDS[openmlDS['name'].str.contains('employee|HR|attrition|credit')].sort_values(by='NumberOfInstances')
# Out:
#          did  \
# 461      461
# 45063  45063
# 44155  44155
# 29        29
# 44098  44098
# 44498  44498
# 42633  42633
# 42632  42632
# 42631  42631
# 42630  42630
# 42629  42629
# 42628  42628
# 44499  44499
# 42627  42627
# 44501  44501
# 44502  44502
# 44096  44096
# 44097  44097
# 45058  45058
# 31        31
# 44500  44500
# 43896  43896
# 43905  43905
# 43897  43897
# 43895  43895
# 43893  43893
# 43696  43696
# 43894  43894
# 44353  44353
# 44354  44354
# 44355  44355
# 44356  44356
# 44357  44357
# 44358  44358
# 44712  44712
# 44711  44711
# 44709  44709
# 44359  44359
# 44360  44360
# 44708  44708
# 44361  44361
# 44710  44710
# 44352  44352
# 44345  44345
# 44350  44350
# 44349  44349
# 44348  44348
# 44347  44347
# 44346  44346
# 44351  44351
# 42125  42125
# 45036  45036
# 45020  45020
# 45016  45016
# 44089  44089
# 43978  43978
# 45027  45027
# 45024  45024
# 42105  42105
# 42477  42477
# 4135    4135
# 43900  43900
# 1597    1597
# 43627  43627
# 124      124
# ...
