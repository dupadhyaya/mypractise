# %% [markdown]
# # csv kit
# - https://csvkit.readthedocs.io/en/latest/tutorial/1_getting_started.html#installing-csvkit

# %%
#!pip install csvkit

# %%
# !csvlook '/Users/du/dup/analytics/projects/mypractise/data/retail.csv' | less -S
# Out:
# | 0      | 1      | 2      | 3      | 4      | 5      | 6      |
# | ------ | ------ | ------ | ------ | ------ | ------ | ------ |
# | Bread  | Wine   | Eggs   | Meat   | Cheese | Pencil | Diaper |
# | Bread  | Cheese | Meat   | Diaper | Wine   | Milk   | Pencil |
# | Cheese | Meat   | Eggs   | Milk   | Wine   |        |        |
# | Cheese | Meat   | Eggs   | Milk   | Wine   |        |        |
# | Meat   | Pencil | Wine   |        |        |        |        |
# | Eggs   | Bread  | Wine   | Pencil | Milk   | Diaper | Bagel  |
# | Wine   | Pencil | Eggs   | Cheese |        |        |        |
# | Bagel  | Bread  | Milk   | Pencil | Diaper |        |        |
# | Bread  | Diaper | Cheese | Milk   | Wine   | Eggs   |        |
# | Bagel  | Wine   | Diaper | Meat   | Pencil | Eggs   | Cheese |
# | Cheese | Meat   | Eggs   | Milk   | Wine   |        |        |
# | Bagel  | Eggs   | Meat   | Bread  | Diaper | Wine   | Milk   |
# ...

# %%
csvloc = '/Users/du/dup/analytics/projects/mypractise/data/retail.csv'
csvloc
# Out:
# '/Users/du/dup/analytics/projects/mypractise/data/retail.csv'

# %%
# !csvstat /Users/du/dup/analytics/projects/mypractise/data/retail.csv
# Out:
#   1. "0"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Non-null values:       315
# 	Unique values:         9
# 	Longest value:         6 characters
# 	Most common values:    Bread (74x)
# 	                       Cheese (56x)
# 	                       Diaper (34x)
# 	                       Meat (32x)
# 	                       Bagel (31x)
#
#   2. "1"
#
# 	Type of data:          Text
# 	Contains null values:  True (excluded from calculations)
# 	Non-null values:       285
# 	Unique values:         10
# 	Longest value:         6 characters
# 	Most common values:    Meat (47x)
# 	                       Bagel (47x)
# 	                       Cheese (35x)
# 	                       Diaper (30x)
# 	                       None (30x)
#
#   3. "2"
#
# 	Type of data:          Text
# 	Contains null values:  True (excluded from calculations)
# 	Non-null values:       245
# 	Unique values:         10
# 	Longest value:         6 characters
# 	Most common values:    None (70x)
# ...

# %%
# !csvcut -n /Users/du/dup/analytics/projects/mypractise/data/retail.csv
# Out:
#   1: 0
#   2: 1
#   3: 2
#   4: 3
#   5: 4
#   6: 5
#   7: 6

# %%
# !csvcut -c 2,5,6 /Users/du/dup/analytics/projects/mypractise/data/retail.csv
# Out:
# 1,4,5
# Wine,Cheese,Pencil
# Cheese,Wine,Milk
# Meat,Wine,
# Meat,Wine,
# Pencil,,
# Bread,Milk,Diaper
# Pencil,,
# Bread,Diaper,
# Diaper,Wine,Eggs
# Wine,Pencil,Eggs
# Meat,Wine,
# Eggs,Diaper,Wine
# Diaper,Meat,
# Cheese,,
# ,,
# Diaper,,
# Bagel,,
# Bagel,,
# ,,
# Cheese,Diaper,Eggs
# Pencil,,
# Eggs,Milk,Pencil
# Bagel,Diaper,
# Wine,Meat,
# Meat,Bagel,Cheese
# ,,
# Meat,Wine,
# Meat,Wine,Cheese
# Bagel,,
# Bread,Milk,Diaper
# Meat,,
# Bagel,Wine,
# Milk,,
# Bagel,,
# Bread,Bagel,
# Cheese,Diaper,
# Bagel,,
# Bagel,,
# ,,
# Bagel,,
# Bagel,,
# ,,
# Wine,Pencil,Bagel
# Eggs,,
# Wine,,
# Bread,Wine,Milk
# Meat,,
# Wine,,
# Meat,Wine,
# Milk,,
# ,,
# Bread,Milk,
# Meat,Wine,
# Meat,,
# Diaper,Bread,
# Milk,Cheese,Eggs
# Eggs,Wine,Milk
# Eggs,,
# Meat,Wine,
# Cheese,Bread,Meat
# Pencil,,
# Cheese,,
# Bagel,,
# Meat,Wine,Diaper
# Cheese,Eggs,
# Diaper,Cheese,Eggs
# Milk,,
# Bagel,,
# Bread,Meat,Pencil
# Bagel,,
# Bread,,
# Milk,,
# Milk,,
# Bread,Meat,
# Meat,,
# Meat,,
# ...

# %%
# !csvcut -c 1,2,3 /Users/du/dup/analytics/projects/mypractise/data/retail.csv | csvlook | head
# Out:
# | 0      | 1      | 2      |
# | ------ | ------ | ------ |
# | Bread  | Wine   | Eggs   |
# | Bread  | Cheese | Meat   |
# | Cheese | Meat   | Eggs   |
# | Cheese | Meat   | Eggs   |
# | Meat   | Pencil | Wine   |
# | Eggs   | Bread  | Wine   |
# | Wine   | Pencil | Eggs   |
# | Bagel  | Bread  | Milk   |

# %%
#in2csv data.xls > data.csv
#Excel to csv
