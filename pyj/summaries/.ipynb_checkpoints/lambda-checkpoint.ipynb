# %% [markdown]
# # lamdba Functions
# -  xx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns

# %%
mtcars = data('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars1 = mtcars.reset_index().rename(columns={'index':'carname'})

# %%
#lambda

# %%
lf1 = lambda x : x + 10
print(lf1(5))
# Out:
# 15

# %%
lf2 = lambda x, y : x + y
print(lf2(2,3))
# Out:
# 5

# %%
str1 = 'Dhiraj Upadhyaya'
upperName = lambda newstr : newstr.upper()
print(upperName(str1))
# Out:
# DHIRAJ UPADHYAYA

# %%
#filter + lambda
li1 = [ 23, 20,5,7,22,97]
finalList = list(filter(lambda x : (x %2 != 0), li1))
finalList  #list only odd nos
# Out:
# [23, 5, 7, 97]

# %%
sum(li1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 sum(li1)
#
# TypeError: 'int' object is not callable

# %%
adults = list(filter(lambda x : x > 18, li1))
adults
# Out:
# [23, 20, 22, 97]

# %% [markdown]
# # map + lambda
# -  map() function in Python takes in a function and a list as an argument. The function is called with a lambda function and a list and a new list is returned which contains all the lambda-modified items returned by that function for each item.

# %%
finalList = list(map(lambda x : x * 2, li1))
finalList
# Out:
# [46, 40, 10, 14, 44, 194]

# %%
snames = ['Dhiraj','Bhagat','Mohan','Sakshi']
upperNames = list(map(lambda x : x.upper(), snames))
upperNames
# Out:
# ['DHIRAJ', 'BHAGAT', 'MOHAN', 'SAKSHI']

# %% [markdown]
# # lambda + Reduce
# - The reduce() function in Python takes in a function and a list as an argument. The function is called with a lambda function and an iterable and a new reduced result is returned. This performs a repetitive operation over the pairs of the iterable. The reduce() function belongs to the functools module

# %%
from functools import reduce

# %%
print(li1)
# Out:
# [23, 20, 5, 7, 22, 97]

# %%
sum2 = reduce((lambda x,y : x +y ), li1)
print(sum2)
# add 2 elements at time
# Out:
# 174

# %%
sum3 = reduce((lambda x,y,z : x + y + z ), li1)
sum3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 sum3 = reduce((lambda x,y, z : x + y + z ), li1)
#       2 sum3
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
mtcars1.head()
# Out:
#              carname   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.apply(lambda x : x * 2 if x.name == 'Mazda RX4' else x/2, axis=1).head()
# increase values of Mazda car by 2
# Out:
#                      mpg   cyl   disp     hp   drat      wt    qsec   vs   am  \
# Mazda RX4          42.00  12.0  320.0  220.0  7.800  5.2400  32.920  0.0  2.0
# Mazda RX4 Wag      10.50   3.0   80.0   55.0  1.950  1.4375   8.510  0.0  0.5
# Datsun 710         11.40   2.0   54.0   46.5  1.925  1.1600   9.305  0.5  0.5
# Hornet 4 Drive     10.70   3.0  129.0   55.0  1.540  1.6075   9.720  0.5  0.0
# Hornet Sportabout   9.35   4.0  180.0   87.5  1.575  1.7200   8.510  0.0  0.0
#
#                    gear  carb
# Mazda RX4           8.0   8.0
# Mazda RX4 Wag       2.0   2.0
# Datsun 710          2.0   0.5
# Hornet 4 Drive      1.5   0.5
# Hornet Sportabout   1.5   1.0

# %%
mtcars.apply(lambda x : x.max() - x.min(), axis=0)
#range of values of each col
# Out:
# mpg      23.500
# cyl       4.000
# disp    400.900
# hp      283.000
# drat      2.170
# wt        3.911
# qsec      8.400
# vs        1.000
# am        1.000
# gear      2.000
# carb      7.000
# dtype: float64

# %%
mtcars.agg(['min','max'], axis=0)
# Out:
#       mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# min  10.4    4   71.1   52  2.76  1.513  14.5   0   0     3     1
# max  33.9    8  472.0  335  4.93  5.424  22.9   1   1     5     8

# %%
mtcars.assign(sumHPMPG = lambda x : x['mpg'] + x['hp'], what = lambda x : x['mpg'].astype('string') + "::" + \
              x['hp'].astype('string')).head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb  sumHPMPG       what
# Mazda RX4             4     131.0  21.0::110
# Mazda RX4 Wag         4     131.0  21.0::110
# Datsun 710            1     115.8   22.8::93
# Hornet 4 Drive        1     131.4  21.4::110
# Hornet Sportabout     2     193.7  18.7::175

# %%
mtcars.astype('string').agg('-'.join, axis=1).head()
# Out:
# Mazda RX4              21.0-6-160.0-110-3.9-2.62-16.46-0-1-4-4
# Mazda RX4 Wag         21.0-6-160.0-110-3.9-2.875-17.02-0-1-4-4
# Datsun 710             22.8-4-108.0-93-3.85-2.32-18.61-1-1-4-1
# Hornet 4 Drive       21.4-6-258.0-110-3.08-3.215-19.44-1-0-3-1
# Hornet Sportabout     18.7-8-360.0-175-3.15-3.44-17.02-0-0-3-2
# dtype: object

# %%
mtcars.reset_index().astype('string').apply(lambda x : '-'.join(x), axis=1).tail()
# Out:
# 27      Lotus Europa-30.4-4-95.1-113-3.77-1.513-16.9-1-1-5-2
# 28    Ford Pantera L-15.8-8-351.0-264-4.22-3.17-14.5-0-1-5-4
# 29      Ferrari Dino-19.7-6-145.0-175-3.62-2.77-15.5-0-1-5-6
# 30     Maserati Bora-15.0-8-301.0-335-3.54-3.57-14.6-0-1-5-8
# 31        Volvo 142E-21.4-4-121.0-109-4.11-2.78-18.6-1-1-4-2
# dtype: object

# %%
mtcars.groupby('gear')['mpg'].transform('sum')
# Out:
# Mazda RX4              294.4
# Mazda RX4 Wag          294.4
# Datsun 710             294.4
# Hornet 4 Drive         241.6
# Hornet Sportabout      241.6
# Valiant                241.6
# Duster 360             241.6
# Merc 240D              294.4
# Merc 230               294.4
# Merc 280               294.4
# Merc 280C              294.4
# Merc 450SE             241.6
# Merc 450SL             241.6
# Merc 450SLC            241.6
# Cadillac Fleetwood     241.6
# Lincoln Continental    241.6
# Chrysler Imperial      241.6
# Fiat 128               294.4
# Honda Civic            294.4
# Toyota Corolla         294.4
# Toyota Corona          241.6
# Dodge Challenger       241.6
# AMC Javelin            241.6
# Camaro Z28             241.6
# Pontiac Firebird       241.6
# Fiat X1-9              294.4
# Porsche 914-2          106.9
# Lotus Europa           106.9
# Ford Pantera L         106.9
# Ferrari Dino           106.9
# Maserati Bora          106.9
# Volvo 142E             294.4
# ...

# %%
mtcars[mtcars['gear']== 4].apply(lambda x : x / x.sum())  # .sum(axis=0)
# Out:
#                      mpg       cyl      disp        hp      drat        wt  \
# Mazda RX4       0.071332  0.107143  0.108386  0.102421  0.080379  0.083439
# Mazda RX4 Wag   0.071332  0.107143  0.108386  0.102421  0.080379  0.091561
# Datsun 710      0.077446  0.071429  0.073161  0.086592  0.079349  0.073885
# Merc 240D       0.082880  0.071429  0.099377  0.057728  0.076051  0.101592
# Merc 230        0.077446  0.071429  0.095380  0.088454  0.080791  0.100318
# Merc 280        0.065217  0.107143  0.113535  0.114525  0.080791  0.109554
# Merc 280C       0.060462  0.107143  0.113535  0.114525  0.080791  0.109554
# Fiat 128        0.110054  0.071429  0.053313  0.061453  0.084089  0.070064
# Honda Civic     0.103261  0.071429  0.051280  0.048417  0.101608  0.051433
# Toyota Corolla  0.115149  0.071429  0.048164  0.060521  0.086974  0.058439
# Fiat X1-9       0.092731  0.071429  0.053516  0.061453  0.084089  0.061624
# ...

# %%
mtcars.set_index('gear').groupby(level=0, as_index=False).apply(lambda x : x / x.sum())
# Out:
#              mpg       cyl      disp        hp      drat        wt      qsec  \
#   gear
# 0 3     0.088576  0.053571  0.052712  0.041635  0.065546  0.055062  0.073253
#   3     0.077401  0.071429  0.073552  0.066238  0.067036  0.058915  0.064134
#   3     0.074917  0.053571  0.045970  0.039743  0.058736  0.059258  0.076193
#   3     0.059189  0.071429  0.073552  0.092733  0.068312  0.061142  0.059688
#   3     0.067881  0.071429  0.056349  0.068130  0.065333  0.069705  0.065566
#   3     0.071606  0.071429  0.056349  0.068130  0.065333  0.063882  0.066320
#   3     0.062914  0.071429  0.056349  0.068130  0.065333  0.064738  0.067827
#   3     0.043046  0.071429  0.096435  0.077593  0.062354  0.089914  0.067752
#   3     0.043046  0.071429  0.093983  0.081378  0.063843  0.092894  0.067149
#   3     0.060844  0.071429  0.089897  0.087055  0.068738  0.091541  0.065642
#   3     0.088990  0.035714  0.024538  0.036715  0.078740  0.042217  0.075401
# ...

# %%
mtcars.groupby('gear')['mpg'].transform(lambda x : 100 * x /x.sum()).round()
# Out:
# Mazda RX4               7.0
# Mazda RX4 Wag           7.0
# Datsun 710              8.0
# Hornet 4 Drive          9.0
# Hornet Sportabout       8.0
# Valiant                 7.0
# Duster 360              6.0
# Merc 240D               8.0
# Merc 230                8.0
# Merc 280                7.0
# Merc 280C               6.0
# Merc 450SE              7.0
# Merc 450SL              7.0
# Merc 450SLC             6.0
# Cadillac Fleetwood      4.0
# Lincoln Continental     4.0
# Chrysler Imperial       6.0
# Fiat 128               11.0
# Honda Civic            10.0
# Toyota Corolla         12.0
# Toyota Corona           9.0
# Dodge Challenger        6.0
# AMC Javelin             6.0
# Camaro Z28              6.0
# Pontiac Firebird        8.0
# Fiat X1-9               9.0
# Porsche 914-2          24.0
# Lotus Europa           28.0
# Ford Pantera L         15.0
# Ferrari Dino           18.0
# Maserati Bora          14.0
# Volvo 142E              7.0
# Name: mpg, dtype: float64
